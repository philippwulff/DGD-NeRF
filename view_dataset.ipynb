# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import numpy as np

absolute_path_color = os.path.join("/", 'mnt', 'raid', 'kirwul', 'deepdeform', 'test', 'seq020', 'color', '000123.jpg')
absolute_path_depth = os.path.join("/", 'mnt', 'raid', 'kirwul', 'deepdeform', 'test', 'seq020', 'depth', '000123.png')
img_color = plt.imread(absolute_path_color)
img_depth = plt.imread(absolute_path_depth)

# %%
plt.imshow(plt.imread("/mnt/raid/kirwul/deepdeform/test/seq020/color/000123.jpg"))
print(img_color)
# Out:
# [[[135 122 113]
#   [136 123 114]
#   [134 121 112]
#   ...
#   [125 123 124]
#   [129 127 128]
#   [ 64  62  65]]
#
#  [[138 125 116]
#   [135 122 113]
#   [137 124 115]
#   ...
#   [255 254 255]
#   [245 243 244]
#   [131 129 132]]
#
#  [[129 116 107]
#   [132 119 110]
#   [142 132 122]
#   ...
#   [250 246 247]
#   [255 254 255]
#   [  4   0   1]]
#
#  ...
#
#  [[ 29  28  26]
#   [ 31  30  28]
#   [ 33  32  30]
#   ...
#   [ 66  51  48]
#   [ 61  47  44]
#   [ 38  24  21]]
#
#  [[ 31  30  28]
#   [ 31  30  28]
#   [ 33  32  30]
#   ...
#   [ 51  37  36]
#   [ 59  45  44]
#   [ 34  23  21]]
#
#  [[ 36  35  33]
#   [ 34  33  31]
#   [ 35  34  32]
#   ...
#   [ 39  25  24]
#   [ 51  37  36]
#   [ 40  29  27]]]

# %%
plt.imshow(plt.imread("/mnt/raid/kirwul/deepdeform/test/seq020/depth/000123.png"))
plt.colorbar()
#print(img_depth)
#unique, occ = np.unique(img_depth, return_counts=True)
#print(unique[0],":",occ[0])
#print(480*640)
print(img_depth[400,200:300])
# Out:
# [0.04011597 0.04049744 0.04055848 0.04060426 0.04060426 0.040589
#  0.04049744 0.04040589 0.04034485 0.04026856 0.0402533  0.0402533
#  0.04026856 0.04029908 0.04031434 0.04034485 0.04042115 0.04049744
#  0.0405127  0.04054322 0.04083314 0.04107729 0.04107729 0.04101625
#  0.04074159 0.04100099 0.04074159 0.04101625 0.04072633 0.04046693
#  0.04078737 0.04075685 0.04078737 0.04080262 0.04081788 0.04074159
#  0.04054322 0.04078737 0.04063477 0.04034485 0.04048219 0.04013123
#  0.04013123 0.04011597 0.04034485 0.04010071 0.04011597 0.04013123
#  0.04016175 0.04019227 0.04032959 0.04005493 0.04007019 0.03996338
#  0.03968872 0.         0.         0.         0.         0.03544671
#  0.03543145 0.03543145 0.03535515 0.03517205 0.03517205 0.03517205
#  0.03515679 0.03537041 0.03541619 0.03541619 0.03541619 0.03543145
#  0.0353399  0.03530938 0.03530938 0.03546197 0.03550774 0.03535515
#  0.03540093 0.03541619 0.03538567 0.03538567 0.03538567 0.03561456
# ...

# %%
from os.path import isdir

p = "/mnt/raid/kirwul/deepdeform/test/seq000"
isdir(p)
files = list(os.walk(p))
files
# Out:
# [('/mnt/raid/kirwul/deepdeform/test/seq000',
#   ['color', 'depth'],
#   ['intrinsics.txt']),
#  ('/mnt/raid/kirwul/deepdeform/test/seq000/color',
#   [],
#   ['000234.jpg',
#    '000171.jpg',
#    '000243.jpg',
#    '000167.jpg',
#    '000292.jpg',
#    '000196.jpg',
#    '000132.jpg',
#    '000368.jpg',
#    '000187.jpg',
#    '000195.jpg',
#    '000156.jpg',
#    '000035.jpg',
#    '000043.jpg',
#    '000003.jpg',
#    '000230.jpg',
#    '000109.jpg',
#    '000269.jpg',
#    '000054.jpg',
#    '000008.jpg',
#    '000342.jpg',
#    '000027.jpg',
#    '000110.jpg',
#    '000304.jpg',
#    '000235.jpg',
#    '000016.jpg',
#    '000248.jpg',
#    '000128.jpg',
#    '000010.jpg',
#    '000202.jpg',
#    '000079.jpg',
#    '000268.jpg',
#    '000168.jpg',
#    '000153.jpg',
#    '000401.jpg',
#    '000009.jpg',
#    '000404.jpg',
#    '000311.jpg',
#    '000348.jpg',
#    '000356.jpg',
#    '000032.jpg',
#    '000155.jpg',
#    '000220.jpg',
#    '000355.jpg',
#    '000313.jpg',
# ...

# %%
"000000.jpg" in files
# Out:
# False
